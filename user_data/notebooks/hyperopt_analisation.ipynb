# %%
# !pip install matplotlib seaborn pandas numpy
# Out:
# Requirement already satisfied: matplotlib in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (3.7.1)
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      --------- ----------------------------- 71.7/293.3 kB 1.9 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (from matplotlib) (4.39.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: pytz>=2020.1 in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\andrii solokh\documents\projects\freqtrade\.env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import json
import os
sns.set()

# %%
def get_opt_path(file_name="", cache = True, trades = False):
    hyperopt_results_path = "../hyperopt_results/"
    if file_name == "":
        last_result_path = hyperopt_results_path + ".last_result.json"
        last_result_file = json.load(open(last_result_path))
        optimization_path = hyperopt_results_path + last_result_file['latest_hyperopt']
    else:
        optimization_path = hyperopt_results_path + file_name
        
    if (os.path.isfile(optimization_path + '.csv') and cache and not trades):
            optimization_path = optimization_path + '.csv'
        
    return optimization_path

# %%
def load_data(file_name="", columns=[], refresh = False, trades = False):
    optimization_path = get_opt_path(file_name, not refresh, trades = trades)
    print('loading:', optimization_path)
    data = pd.DataFrame()
    trades = pd.DataFrame()
    if optimization_path.endswith('.csv') and not refresh:
        data = pd.read_csv(optimization_path)
    else:
        with open(optimization_path) as fp:
            while True:        
                line = fp.readline()        
                if not line:
                    break
                line_json = json.loads(line)
                param_columns = ["loss", *line_json["params_dict"]]
                line_trades = pd.DataFrame(line_json["results_metrics"]["trades"])
                values = [line_json["loss"], *list(line_json["params_dict"].values())]
                line_data = pd.DataFrame([values], columns = param_columns)
                data = pd.concat([data, line_data])
                trades = pd.concat([trades, line_trades])
    if len(columns) != 0:
        print('reordering columns: ')
        print(data.columns.tolist())
        print(columns)
        data = data[columns]
    if not optimization_path.endswith('.csv'):
        print('saving csv: ', optimization_path + '.csv')
        data.to_csv(optimization_path + '.csv')
    return data, trades

# %%
def hist_loss(data):
    loss = data['loss']
    sns.histplot(loss)
    mean = loss.mean()
    std = loss.std()
    plt.axvline(x=mean, ls='--', lw=1)
    plt.axvline(x=mean - std, ls='--', lw=.5)
    plt.axvline(x=mean + std, ls='--', lw=.5)
    plt.show()

# %%
def hist_params(data):
    params_number = len(data.columns) - 1 # exclude "loss" column
    columns_number = 3
    rows_number = int(params_number / columns_number) + 1
    axes_number = rows_number * columns_number
    
    row_height = 8
    fig_height = rows_number * row_height
    
    fig, axes = plt.subplots(rows_number , columns_number, figsize=(25, fig_height))
    
    for index in range(1, params_number + 1):
        key = data.columns[index]
        
        row_index = int((index - 1) / columns_number)
        column_index = (index - 1) % columns_number
        ax = axes[row_index, column_index]
        
        sns.histplot(data[key], ax = ax)
        
        if data[key].dtype.kind != 'O':
            mean = data[key].mean()
            std = data[key].std()
            ax.axvline(x=mean, ls='--', lw=1)
            ax.axvline(x=mean - std, ls='--', lw=.5)
            ax.axvline(x=mean + std, ls='--', lw=.5)
    
    for index in range(axes_number - 1, params_number - 1, -1):
        row_index = int(index / columns_number)
        column_index = index % columns_number
        axes[row_index, column_index].remove()
    
    plt.show()

# %%
def getCombinations(seq):
    combinations = list()
    for i in range(0,len(seq)):
        for j in range(i+1,len(seq)):
            combinations.append([seq[i],seq[j]])
    return combinations

# %%
def binify(data_i, bins = 10):
    data = data_i.copy()
    for index in range(1, len(data.columns)):
        key = data.columns[index]
        bins_list = []
        if data_i[key].dtype.kind == 'O':
            # bins_list = data_i[key].unique()
            data[key] = data_i[key]
        else:
            bins_list = np.linspace(data[key].min(), data[key].max(), bins)
            data[key] = bins_list[np.digitize(data[key], bins_list, True)]
    return data

# %%
from matplotlib.ticker import MultipleLocator, FuncFormatter

def plot_heatmaps(data, bins = 10):
    bined_data = binify(data, bins)
    index = pd.MultiIndex.from_frame(bined_data[data.columns[1:]])
    series = pd.Series(data['loss'].values, index = index)
    combinations = getCombinations(data.columns[1:])
    best_params = []
    
    columns_number = len(data.columns) - 1
    rows_number = columns_number
    
    fig, axes = plt.subplots(rows_number, columns_number, figsize=(25, 20))
    column = 0
    row = 1
    for combination in combinations:
        method = 'linear'
        limit_direction = 'backward'
        heatmap = series.groupby(combination).mean().unstack().transpose()
        
        if row == rows_number:
            column += 1
            row = column + 1
        ax = axes[row, column]
        
        sns.heatmap(heatmap, cmap='magma_r', ax = ax, cbar=False)
        ax.margins(0)
        if column != 0:
            ax.set_yticklabels([])
        if row + 1 != rows_number:
            ax.set_xticklabels([])
             
        ax.set_title("")
        ax.set_ylabel("")
        ax.set_xlabel("")
        
        row += 1
    
    # plot partial dependecies
    index = 0
    for column in data.columns:
        if column == 'loss':
            continue
        objective = series.groupby([column]).mean()
        rolling_mean = objective.rolling(max(2,int(objective.size / 4)), center=True, min_periods=1).mean()
        ax = axes[index,index]
        ax.xaxis.set_ticks_position('top')
        ax.yaxis.set_ticks_position('right')
        ax.axvline(x=rolling_mean.idxmin(), ls='--', lw=1, color='orange')
        ax.plot(objective)
        ax.plot(rolling_mean)
        ax.set_title(column)
        ax.margins(0)
        
        best_params.append((column, rolling_mean.idxmin()))
        
        index += 1
        
    # remove not needed axes
    for i in range(columns_number):
        for j in range(columns_number):
            if i < j:
                axes[i, j].remove()
    fig.tight_layout()
    
    plt.show()
    
    print(best_params)

# %%
# columns = ['loss','over_bought', 'over_sold', 'rsi_length', 'stoch_length', 'take_profit', 'stoploss','enter_method', 'exit_method']
columns = []
file_name = ''
data, trades = load_data(file_name, columns=columns, trades=True)
hist_params(data)
hist_loss(data)
sns.histplot(trades['profit_ratio'], kde=True, stat="probability")
print('mean',trades['profit_ratio'].mean())
print('std',trades['profit_ratio'].std())
plot_heatmaps(data, 50)
# Out:
# loading: ../hyperopt_results/strategy_FreqaiExampleStrategy_2023-03-25_23-01-30.fthypt
# saving csv:  ../hyperopt_results/strategy_FreqaiExampleStrategy_2023-03-25_23-01-30.fthypt.csv
# mean -0.00013608184072058524
# std 0.01187030287697976
