# %% [markdown]
# **Some words...**
#
# This investigation was conducted in an endeavor to identify trading patterns that could subsequently be employed within the trading system.
#
# **Dataset**
#
# - The dataset has been generated by the Freqai trading bot.
# - It comprises a trading pair dataset for ADA/USDT, which also includes BTC/USDT features.
# - All features exhibit a shift of 5 ticks, meaning each sample encompasses values from the past 5 minutes.
# - All features are scaled using the MinMaxScaler within the range of -1 to 1.
# - Among the features are RSI, BB bounds, raw prices, and percentage change per tick.
# - Certain features are observed over 15-minute and 1-hour periods.
# - The target variable represents the change in price per tick (minute), where a value of -0.01 denotes a 1% decrease.
#
# **Attempted Approaches**
#
# - Model tuning did not yield any significant results, with performance improvements of less than 1% compared to the default parameters.
# - Adjusting the prediction horizon and timeframe resulted in increased root mean square error (RMSE), indicating even poorer predictions.
# - Additional feature selection and removal also failed to provide valuable outcomes, with RMSE changes of only 1%.
# - Attempts were made to predict the BTC/USDT pair exclusively, but performance remained consistent.
# - Sample weighting was explored, prioritizing strong signals, which led to decreased RMSE. However, analyzing the residual plot revealed that although rare samples performed better in the training set, there was no noticeable improvement in the test set performance.
# - Outliers (samples with a standard deviation greater than 3) were both removed and included, but they had no impact on the test and train sets.
#
# **Conclusions**
#
# No practical applications for live trading were identified. The model was unable to detect patterns in the training set that would yield predictions better than the mean of the test set.
#
# **Ideas**
#
# Residual plots in the training set indicate that predictions greater than 0.1 and less than -0.1 are likely to indicate a change in direction. Further analysis should be conducted to explore the reasons behind these occurrences and determine if they can be utilized in any way.

# %% [markdown]
# # Imports

# %%
import joblib
import json
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import optuna
import warnings
from denseweight import DenseWeight
from xgboost import XGBRegressor
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import r2_score

warnings.filterwarnings("ignore")
xgb.set_config(verbosity=1)

# %% [markdown]
# # Declare dataset paths

# %%
models_path = "../models"
name = '1m_label-1_shift-5_periods-1-BTC'
number = 2
symbol = 'ADA'
lowed_symbol = symbol.lower()
code = "1672876800"
model_dir_path = models_path + f"/{name}-{number}/sub-train-{symbol}_{code}"
metadata_path = model_dir_path + f"/cb_{lowed_symbol}_{code}_metadata.json"
features_path = model_dir_path + f"/cb_{lowed_symbol}_{code}_trained_df.pkl"
labels_path = model_dir_path + f"/cb_{lowed_symbol}_{code}_trained_labels_df.pkl"
model_path = model_dir_path + f"/cb_{lowed_symbol}_{code}_model.joblib"

# %% [markdown]
# # Load dataset

# %%
def load_metadata():
    global metadata_path
    with open(metadata_path, "r") as f:
        return json.load(f)


def load_ds():
    global features_path, labels_path
    with open(features_path, "rb") as f:
        X = pickle.load(f)

    with open(labels_path, "rb") as f:
        Y = pickle.load(f)

    return X, Y


def load_model():
    return joblib.load(model_path)

# %%
metadata = load_metadata()
X, Y = load_ds()
label_keys = Y.keys().tolist()
model = load_model()

# %% [markdown]
# # Prepare Dataset

# %%
def revert_scale(values, min_value, max_value):
    values_clone = values.copy()
    return min_value + (values_clone + 1.0) * 0.5 * (max_value - min_value)

def revert(values):
    return revert_scale(values, metadata["&-s_close_min"], metadata["&-s_close_max"])

def rescale(Y):
    return 2 * (Y - Y.min()) / (Y.max() - Y.min()) - 1

def get_indexes_wo_outliers(df, column, std=3):
    return df[abs((df[column].mean() - df[column] ) / df[column].std()) < std].index

def filterout_by_std(X, Y, std):
    indexes = get_indexes_wo_outliers(Y, '&-s_close', std)
    reverted = revert(Y)
    filtered_reverted = reverted.loc[indexes]

    rescaled = rescale(filtered_reverted)

    return X.loc[indexes], rescaled

# %%
train_X, train_Y =  filterout_by_std(X, Y, 10)

# %% [markdown]
# # Filterout features

# %%
# filter out columns that have shift
def filter_out_columns(train_X, column):
    columns_to_filterout = train_X.filter(regex=column).columns.tolist()
    columns_wo_shift = train_X.columns[~train_X.columns.isin(columns_to_filterout)].tolist()
    train_X = train_X[columns_wo_shift]
    return train_X


def filter():
    train_X = filter_out_columns(train_X, "sma")
    train_X = filter_out_columns(train_X, "ema")
    train_X = filter_out_columns(train_X, "raw")
    train_X = filter_out_columns(train_X, "shift")

# %%
# X = filter_out_columns(X, "shift")

# %% [markdown]
# # Sample weighting

# %%
def get_weights(labels, alpha=1):
    dw = DenseWeight(alpha=alpha)
    dw.fit(labels)
    counts, bins = np.histogram(labels, bins=100)

    def func(v):
        return pow(v, 7)

    density = func(dw.eval(bins))
    return func(dw.weights)

# %%
weights = get_weights(train_Y['&-s_close'].values, 0)

# %%
def plot_datasets(X):
    for column in X.columns:
        plt.title(column)
        plt.hist(X[column], bins=100)
        plt.show()

# %% [markdown]
# # Dataset split

# %%
X_train, X_test, y_train, y_test, train_weights, test_weights = train_test_split(
    train_X, train_Y, weights, test_size=0.2, random_state=10, shuffle=True
)

# %% [markdown]
# # Model init

# %%
def get_model(alpha, std):
    global X, Y

    params = {
        "max_depth": 10,
        "learning_rate": 0.07109375514004197,
        "n_estimators": 10000,
        "min_child_weight": 17,
        "gamma": 0.0022487781882634316,
        "subsample": 0.790320036578317,
        "colsample_bytree": 0.9940781270525615,
        "reg_alpha": 4.573097358976904e-06,
        "reg_lambda": 7.186304012143283e-07
    }

    train_X, train_Y =  filterout_by_std(X, Y, std)
    weights = get_weights(train_Y["&-s_close"].values, alpha=alpha)

    X_train, X_test, y_train, y_test, train_weights, test_weights = train_test_split(
        train_X, train_Y, weights, test_size=0.1, random_state=10, shuffle=False
    )

    model = XGBRegressor(tree_method = "gpu_hist", **params)
    model.fit(
        X_train,
        y_train,
        sample_weight=train_weights,
        eval_set=[(X_test, y_test)],
        sample_weight_eval_set=[(test_weights)],
        early_stopping_rounds=5,
        verbose=True,
    )

    predictions = model.predict(X_test)

    print('R2', r2_score(y_test["&-s_close"], predictions, sample_weight = test_weights))

    return model, X_train, y_train, X_test, y_test

# %%
model, X_train, y_train, X_test, y_test = get_model(0, 10)

# %% [markdown]
# # Plot residual charts

# %%
# %matplotlib ipympl

def residual_plot(model, X, y, column = None):
    predictions = model.predict(X)
    residuals = (y["&-s_close"] - predictions)
    mean = y['&-s_close'].mean()
    critical_line = np.linspace(-1, 1, 100)

    x_line = y['&-s_close'] if column == None else X[column]

    plt.close()
    plt.figure(figsize=(17, 10))
    sns.scatterplot(x=x_line, y=residuals, s=1)
    plt.plot(critical_line + mean, critical_line, color="red")
    plt.vlines(mean, -1, 1, color="grey")
    plt.show()

# %%
residual_plot(model, X_train, y_train)

# %%
residual_plot(model, X_test, y_test)

# %% [markdown]
# # Playground

# %%
params = {
    "max_depth": 10,
    "learning_rate": 0.07109375514004197,
    "n_estimators": 10000,
    "min_child_weight": 17,
    "gamma": 0.0022487781882634316,
    "subsample": 0.790320036578317,
    "colsample_bytree": 0.9940781270525615,
    "reg_alpha": 4.573097358976904e-06,
    "reg_lambda": 7.186304012143283e-07
}

model = XGBRegressor(tree_method = "gpu_hist", **params)

model.fit(
    X_train,
    y_train,
    sample_weight=train_weights,
    eval_set=[(X_train, y_train), (X_test, y_test)],
    sample_weight_eval_set=[(train_weights), (test_weights)],
    early_stopping_rounds=5,
    verbose=True,
)
# Out:
# [0]	validation_0-rmse:0.47294	validation_1-rmse:0.47281
# [1]	validation_0-rmse:0.44059	validation_1-rmse:0.44050
# [2]	validation_0-rmse:0.41064	validation_1-rmse:0.41059
# [3]	validation_0-rmse:0.38291	validation_1-rmse:0.38290
# [4]	validation_0-rmse:0.35724	validation_1-rmse:0.35728
# [5]	validation_0-rmse:0.33352	validation_1-rmse:0.33361
# [6]	validation_0-rmse:0.31160	validation_1-rmse:0.31174
# [7]	validation_0-rmse:0.29135	validation_1-rmse:0.29156
# [8]	validation_0-rmse:0.27267	validation_1-rmse:0.27294
# [9]	validation_0-rmse:0.25545	validation_1-rmse:0.25579
# [10]	validation_0-rmse:0.23960	validation_1-rmse:0.24002
# [11]	validation_0-rmse:0.22502	validation_1-rmse:0.22552
# [12]	validation_0-rmse:0.21163	validation_1-rmse:0.21222
# [13]	validation_0-rmse:0.19934	validation_1-rmse:0.20003
# [14]	validation_0-rmse:0.18810	validation_1-rmse:0.18888
# [15]	validation_0-rmse:0.17780	validation_1-rmse:0.17869
# [16]	validation_0-rmse:0.16841	validation_1-rmse:0.16942
# [17]	validation_0-rmse:0.15987	validation_1-rmse:0.16099
# [18]	validation_0-rmse:0.15212	validation_1-rmse:0.15336
# [19]	validation_0-rmse:0.14506	validation_1-rmse:0.14645
# [20]	validation_0-rmse:0.13869	validation_1-rmse:0.14021
# [21]	validation_0-rmse:0.13294	validation_1-rmse:0.13459
# [22]	validation_0-rmse:0.12778	validation_1-rmse:0.12956
# [23]	validation_0-rmse:0.12312	validation_1-rmse:0.12504
# [24]	validation_0-rmse:0.11895	validation_1-rmse:0.12102
# [25]	validation_0-rmse:0.11522	validation_1-rmse:0.11744
# [26]	validation_0-rmse:0.11189	validation_1-rmse:0.11426
# [27]	validation_0-rmse:0.10895	validation_1-rmse:0.11144
# [28]	validation_0-rmse:0.10631	validation_1-rmse:0.10895
# [29]	validation_0-rmse:0.10395	validation_1-rmse:0.10676
# [30]	validation_0-rmse:0.10189	validation_1-rmse:0.10482
# [31]	validation_0-rmse:0.10005	validation_1-rmse:0.10313
# [32]	validation_0-rmse:0.09846	validation_1-rmse:0.10166
# [33]	validation_0-rmse:0.09705	validation_1-rmse:0.10035
# [34]	validation_0-rmse:0.09581	validation_1-rmse:0.09922
# [35]	validation_0-rmse:0.09469	validation_1-rmse:0.09823
# [36]	validation_0-rmse:0.09373	validation_1-rmse:0.09738
# [37]	validation_0-rmse:0.09286	validation_1-rmse:0.09663
# [38]	validation_0-rmse:0.09212	validation_1-rmse:0.09598
# [39]	validation_0-rmse:0.09148	validation_1-rmse:0.09541
# [40]	validation_0-rmse:0.09092	validation_1-rmse:0.09492
# [41]	validation_0-rmse:0.09038	validation_1-rmse:0.09449
# [42]	validation_0-rmse:0.08992	validation_1-rmse:0.09413
# [43]	validation_0-rmse:0.08952	validation_1-rmse:0.09381
# [44]	validation_0-rmse:0.08916	validation_1-rmse:0.09354
# [45]	validation_0-rmse:0.08882	validation_1-rmse:0.09331
# [46]	validation_0-rmse:0.08853	validation_1-rmse:0.09311
# [47]	validation_0-rmse:0.08827	validation_1-rmse:0.09293
# [48]	validation_0-rmse:0.08804	validation_1-rmse:0.09279
# [49]	validation_0-rmse:0.08783	validation_1-rmse:0.09266
# [50]	validation_0-rmse:0.08763	validation_1-rmse:0.09254
# [51]	validation_0-rmse:0.08744	validation_1-rmse:0.09244
# [52]	validation_0-rmse:0.08727	validation_1-rmse:0.09235
# [53]	validation_0-rmse:0.08714	validation_1-rmse:0.09228
# [54]	validation_0-rmse:0.08700	validation_1-rmse:0.09222
# [55]	validation_0-rmse:0.08688	validation_1-rmse:0.09217
# [56]	validation_0-rmse:0.08675	validation_1-rmse:0.09212
# [57]	validation_0-rmse:0.08665	validation_1-rmse:0.09208
# [58]	validation_0-rmse:0.08652	validation_1-rmse:0.09205
# [59]	validation_0-rmse:0.08641	validation_1-rmse:0.09202
# [60]	validation_0-rmse:0.08632	validation_1-rmse:0.09199
# [61]	validation_0-rmse:0.08622	validation_1-rmse:0.09197
# [62]	validation_0-rmse:0.08613	validation_1-rmse:0.09196
# [63]	validation_0-rmse:0.08606	validation_1-rmse:0.09194
# [64]	validation_0-rmse:0.08597	validation_1-rmse:0.09193
# [65]	validation_0-rmse:0.08591	validation_1-rmse:0.09192
# [66]	validation_0-rmse:0.08582	validation_1-rmse:0.09191
# [67]	validation_0-rmse:0.08575	validation_1-rmse:0.09190
# [68]	validation_0-rmse:0.08567	validation_1-rmse:0.09191
# [69]	validation_0-rmse:0.08559	validation_1-rmse:0.09189
# [70]	validation_0-rmse:0.08552	validation_1-rmse:0.09189
# [71]	validation_0-rmse:0.08545	validation_1-rmse:0.09188
# [72]	validation_0-rmse:0.08534	validation_1-rmse:0.09189
# [73]	validation_0-rmse:0.08530	validation_1-rmse:0.09188
# [74]	validation_0-rmse:0.08524	validation_1-rmse:0.09188
# [75]	validation_0-rmse:0.08516	validation_1-rmse:0.09189
# [76]	validation_0-rmse:0.08508	validation_1-rmse:0.09189
# [77]	validation_0-rmse:0.08502	validation_1-rmse:0.09188
# [78]	validation_0-rmse:0.08496	validation_1-rmse:0.09188
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9940781270525615, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.0022487781882634316, gpu_id=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.07109375514004197, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=17, missing=nan, monotone_constraints=None,
#              n_estimators=10000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
residual_plot(model, X_test, y_test)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# No such comm: 5580f80594734ab08e8cae734c8964e2

# %%
residual_plot(model, X_train, y_train)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Analize best predictions

# %%
predictions = model.predict(X_train)

# %%
left_side_indexes = predictions < -0.1
right_side_indexes = predictions > 0.1
best_X = X_train[left_side_indexes | right_side_indexes]
best_Y = y_train[left_side_indexes | right_side_indexes]

# %%
# %matplotlib inline

for column in best_X.columns:
    plt.title(column)
    plt.hist(best_X[column], bins=100, log=True)
    plt.hist(X_train[column], bins=100, log=True, alpha=0.5)
    plt.show()

# %% [markdown]
# # Important features

# %%
def plot_feature_importance(number):
    plt.close()
    plt.margins(x=50, y = 50)
    fig, ax = plt.subplots(figsize=(15, 30))
    xgb.plot_importance(model, max_num_features=number, height=0.1, ax=ax)
    plt.show()

# %%
# %matplotlib inline
plot_feature_importance(100)

# %% [markdown]
# # Hypertuning

# %%
train_X, train_Y =  filterout_by_std(X, Y, 10)
weights = get_weights(train_Y["&-s_close"].values, alpha=0)

X_train, X_test, y_train, y_test, train_weights, test_weights = train_test_split(
    train_X, train_Y, weights, test_size=0.05, random_state=10, shuffle=False
)

# %%
def objective(trial):
    """Define the objective function"""

    params = {
        "max_depth": trial.suggest_int("max_depth", 5, 30),
        "learning_rate": trial.suggest_loguniform("learning_rate", 0.01, 1.0),
        "n_estimators": trial.suggest_int("n_estimators", 500, 500),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 20),
        "gamma": trial.suggest_loguniform("gamma", 1e-8, 1.0),
        "subsample": trial.suggest_loguniform("subsample", 0.01, 1.0),
        "colsample_bytree": trial.suggest_loguniform("colsample_bytree", 0.01, 1.0),
        "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-8, 1.0),
        "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-8, 1.0),
        "eval_metric": r2_score,
        "n_jobs": -1,
        "tree_method": "gpu_hist",
    }

    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "validation_0-rmse")

    # Fit the model
    optuna_model = XGBRegressor(**params)

    optuna_model.fit(
        X_train,
        y_train,
        early_stopping_rounds=10,
        sample_weight=train_weights,
        eval_set=[(X_test, y_test)],
        sample_weight_eval_set=[(test_weights)],
        verbose=False,
        callbacks=[pruning_callback],
    )

    # Make predictions
    y_pred = optuna_model.predict(X_test)

    # Evaluate predictions
    mse = mean_squared_error(y_test, y_pred, squared=False, sample_weight=test_weights)
    return mse

# %%
study = optuna.create_study(pruner=optuna.pruners.MedianPruner(n_warmup_steps=50), direction="minimize")
study.optimize(objective, n_trials=100)

# %%
print("Number of finished trials: {}".format(len(study.trials)))
print("Best trial:")

trial = study.best_trial

print("  Value: {}".format(trial.value))
print("  Params: ")

for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# %%
# trial.params["n_estimators"] = 2000
model = XGBRegressor(tree_method = "gpu_hist",**trial.params)
model.fit(
    X,
    y,
    sample_weight=train_weights,
    eval_set=[(X_test, y_test)],
    sample_weight_eval_set=[(test_weights)],
    verbose=True,
    early_stopping_rounds=10
)

# %% [markdown]
# # Save model

# %%
joblib.dump(model, model_path)
